# %%
from battery_utils import (
    load_battery_data,
    process_battery,
    plot_results,
    # plot_temperature_curves
)

# ➤ 資料夾路徑
directory_path = 'C:/Users/王奕傑/Desktop/CALCE-main/dataset/'

# ------------------------------------
# 處理電壓 / 電流等數據（來自 CS2_33）
# ------------------------------------
battery_name = 'CS2_38'
print(f'Loading Battery Dataset: {battery_name} ...')
path_sorted = load_battery_data(battery_name, directory_path)
df_result = process_battery(path_sorted, battery_name)
plot_results(df_result, battery_name)
# Out:
# Loading Battery Dataset: CS2_38 ...
# c:\Users\王奕傑\Desktop\CALCE-main\battery_utils.py:162: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels(['New', 'Aged'], fontsize=12)
# 充電曲線數據已儲存至 C:\Users\王奕傑\Desktop\CALCE-main\data2\CS2_38_charging_data.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\王奕傑\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
# ------------------------------------
# 額外處理溫度資料（來自另一顆電池 CS2_8_1）
# ------------------------------------
# plot_temperature_curves("CS2_8_1", directory_path)

# %%
# 執行健康特徵計算並繪圖（多檔案畫在同一張圖上）
# 從 HF.py 匯入所需的函數
# from HF import process_all_files_in_directory  # 只需要這一個函數
# process_all_files_in_directory(directory_path)

# %%
from HF2 import process_voltage_features_in_directory, process_current_features_in_directory

if __name__ == "__main__":
    directory_path = r"C:\Users\王奕傑\Desktop\CALCE-main\dataset\CS2_33"

    # ➤ 呼叫電壓與電流特徵提取與繪圖
    process_voltage_features_in_directory(directory_path)
    process_current_features_in_directory(directory_path)
# Out:
# 開始處理電壓特徵，目錄: C:\Users\王奕傑\Desktop\CALCE-main\dataset\CS2_33
# 正在處理檔案（電壓）: C:\Users\王奕傑\Desktop\CALCE-main\dataset\CS2_33\CS2_33_10_04_10.xlsx
# ✅ 電壓特徵提取成功:              Voltage_Mean  Voltage_Std  Voltage_Max  Voltage_Min  \
# Cycle_Index
# 1                3.849414     0.226743     4.200227     2.699537
# 2                3.845904     0.234062     4.200227     2.699699
# 3                3.818650     0.222790     4.200065     2.699375
# 4                3.841276     0.231394     4.200227     2.699699
# 5                3.844064     0.232424     4.200227     2.699861
#
#              Voltage_Range  Voltage_Q25  Voltage_Q50  Voltage_Q75
# Cycle_Index
# 1                 1.500690     3.705140     3.882885     4.000572
# 2                 1.500528     3.706922     3.879970     4.000977
# 3                 1.500690     3.695137     3.850649     3.957928
# 4                 1.500528     3.701455     3.873652     3.994822
# 5                 1.500366     3.702265     3.878026     3.998709
# ...

# %%
import os
# from Jinhsi import plot_avg_voltage_over_cycles, plot_max_voltage_over_cycles, plot_min_voltage_over_cycles
from Jinhsi import plot_voltage_stats_over_cycles
#from Changli import plot_avg_current_over_cycles, plot_max_current_over_cycles, plot_min_current_over_cycles
#from Shorekeeper import plot_discharge_capacity_over_cycles

if __name__ == "__main__":
    directory_path = r"C:\Users\王奕傑\Desktop\CALCE-main\dataset\CS2_33"
    path_sorted = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.xlsx')]

    # plot_avg_voltage_over_cycles(path_sorted)
    # plot_max_voltage_over_cycles(path_sorted)
    # plot_min_voltage_over_cycles(path_sorted)
    # plot_avg_current_over_cycles(path_sorted)
    # plot_max_current_over_cycles(path_sorted)
    # plot_min_current_over_cycles(path_sorted)
    # plot_discharge_capacity_over_cycles(path_sorted)

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\王奕傑\AppData\Local\Programs\Python\Python311\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
